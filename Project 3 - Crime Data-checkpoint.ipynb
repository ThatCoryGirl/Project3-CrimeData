# %% [markdown]
# # **Objective**: Our project will investigate drug poisoning and fatalities, particularly examining the increasing prevalence of fentanyl, a powerful synthetic opioid approved by the FDA for pain relief and anesthesia. We aim to analyze fentanyl data alongside other substances. We are presenting statistics on fatalities and poisonings categorized by age, gender, and zip code. Additionally, we seek to correlate zip codes with income levels to provide a comprehensive understanding of the impact of drug use on different socioeconomical levels. Our data was gathered from 1999 to 2021.

# %%
# Dependencies
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
from pathlib import Path
from scipy import stats
import hvplot.pandas
import seaborn as sns

#When installing Folium, Branca automatically installs as well. It is used to manipulate HTML, CSS, or Javascript
import folium
import branca
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="f0672096-4bf3-41db-85d4-5e6d7bfe80f9" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"81ace63a-6ff0-4e36-8135-274e25674b12":{"version":"3.3.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"2c73aac4d7174352885797b579608988","client_comm_id":"a6eff3e9987a49bd948c8c1c15e462dd"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"81ace63a-6ff0-4e36-8135-274e25674b12","roots":{"p1002":"f0672096-4bf3-41db-85d4-5e6d7bfe80f9"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# Store file pathing to variables
death_data = Path("resources/Death.csv")
rates_data = Path("resources/Rates.csv")
# Read files
death_data_info = pd.read_csv(death_data)
rates_data_info = pd.read_csv(rates_data)
#sort file
sorted_by_drug_deaths = death_data_info.sort_values(by=['Year', 'Substance', 'Gender'])
# Print head()
sorted_by_drug_deaths.tail(900)
# Out:
#      Year      Gender                                        Intent  \
# 840  2007  Both sexes  All (preventable, intentional, undetermined)
# 850  2007  Both sexes                        Preventable/accidental
# 860  2007      Female  All (preventable, intentional, undetermined)
# 870  2007      Female                        Preventable/accidental
# 880  2007        Male  All (preventable, intentional, undetermined)
# ..    ...         ...                                           ...
# 19   2021  Both sexes                        Preventable/accidental
# 29   2021      Female  All (preventable, intentional, undetermined)
# 39   2021      Female                        Preventable/accidental
# 49   2021        Male  All (preventable, intentional, undetermined)
# 59   2021        Male                        Preventable/accidental
#
#                                     Substance  Under1_year  1to4_Years  \
# 840                                 All drugs           33          44
# 850                                 All drugs           13          21
# 860                                 All drugs           15          23
# 870                                 All drugs            4          10
# 880                                 All drugs           18          21
# ..                                        ...          ...         ...
# 19   Psychostimulants – incl. methamphetamine           12           0
# 29   Psychostimulants – incl. methamphetamine           10           0
# 39   Psychostimulants – incl. methamphetamine            0           0
# 49   Psychostimulants – incl. methamphetamine           19           0
# 59   Psychostimulants – incl. methamphetamine            0           0
#
#      5to14_years  15to24_years  25to34_years  35to44_years  45to54_years  \
# 840           74          3550          6663          9152         11012
# 850           53          2927          5418          7123          8394
# 860           32           883          2001          3463          4696
# 870           20           677          1474          2524          3322
# 880           42          2667          4662          5689          6316
# ..           ...           ...           ...           ...           ...
# 19          1430          7254          8935          7115             0
# 29           541          2119          2700          2072             0
# 39           508          2044          2598          1986             0
# 49           961          5359          6520          5243             0
# 59           922          5210          6337          5129             0
#
#      55to64_years  65to74_years  75to84_years  85Plus_years
# 840          4043           791           418           226
# 850          2807           481           267           152
# 860          1809           393           248           148
# 870          1130           207           155           106
# 880          2234           398           170            78
# ..            ...           ...           ...           ...
# 19           5545          1241            62             0
# 29           1499           252            15             0
# 39           1461           249            14             0
# 49           4144          1008            52             0
# 59           4084           992            48             0
#
# [900 rows x 15 columns]

# %%
drug_1999_deaths = sorted_by_drug_deaths[sorted_by_drug_deaths['Year'] == 1999]
drug_1999_deaths.head()
# Out:
#       Year      Gender                                        Intent  \
# 1320  1999  Both sexes  All (preventable, intentional, undetermined)
# 1330  1999  Both sexes                        Preventable/accidental
# 1340  1999      Female  All (preventable, intentional, undetermined)
# 1350  1999      Female                        Preventable/accidental
# 1360  1999        Male  All (preventable, intentional, undetermined)
#
#       Substance  Under1_year  1to4_Years  5to14_years  15to24_years  \
# 1320  All drugs           20          25           29          1240
# 1330  All drugs            8          16           16           849
# 1340  All drugs            6          13           14           346
# 1350  All drugs            1           8            7           186
# 1360  All drugs           14          12           15           894
#
#       25to34_years  35to44_years  45to54_years  55to64_years  65to74_years  \
# 1320          3236          6295          4067           991           434
# 1330          2232          4293          2650           554           221
# 1340           914          1983          1344           431           212
# 1350           503          1155           693           190           100
# 1360          2322          4312          2723           560           222
#
#       75to84_years  85Plus_years
# 1320           340           156
# 1330           192           115
# 1340           219           103
# 1350           121            76
# 1360           121            53

# %%
drug_2000_deaths = sorted_by_drug_deaths[sorted_by_drug_deaths['Year'] == 2000]
drug_2000_deaths.head()
# Out:
#       Year      Gender                                        Intent  \
# 1260  2000  Both sexes  All (preventable, intentional, undetermined)
# 1270  2000  Both sexes                        Preventable/accidental
# 1280  2000      Female  All (preventable, intentional, undetermined)
# 1290  2000      Female                        Preventable/accidental
# 1300  2000        Male  All (preventable, intentional, undetermined)
#
#       Substance  Under1_year  1to4_Years  5to14_years  15to24_years  \
# 1260  All drugs           18          14           42          1435
# 1270  All drugs            9          10           17          1045
# 1280  All drugs            6           2           18           369
# 1290  All drugs            3           2            8           221
# 1300  All drugs           12          12           24          1066
#
#       25to34_years  35to44_years  45to54_years  55to64_years  65to74_years  \
# 1260          3169          6469          4389          1013           371
# 1270          2243          4441          2863           555           207
# 1280           902          2089          1478           497           199
# 1290           540          1242           786           245            97
# 1300          2267          4380          2911           516           172
#
#       75to84_years  85Plus_years
# 1260           295           188
# 1270           176           139
# 1280           175           116
# 1290           114            85
# 1300           120            72

# %%
drug_2001_deaths = sorted_by_drug_deaths[sorted_by_drug_deaths['Year'] == 2001]
drug_2001_deaths.head()
# Out:
#       Year      Gender                                        Intent  \
# 1200  2001  Both sexes  All (preventable, intentional, undetermined)
# 1210  2001  Both sexes                        Preventable/accidental
# 1220  2001      Female  All (preventable, intentional, undetermined)
# 1230  2001      Female                        Preventable/accidental
# 1240  2001        Male  All (preventable, intentional, undetermined)
#
#       Substance  Under1_year  1to4_Years  5to14_years  15to24_years  \
# 1200  All drugs           22          26           43          1700
# 1210  All drugs            9          18           23          1237
# 1220  All drugs            8           5           22           438
# 1230  All drugs            5           3           12           257
# 1240  All drugs           14          21           21          1262
#
#       25to34_years  35to44_years  45to54_years  55to64_years  65to74_years  \
# 1200          3410          6968          5115          1185           440
# 1210          2388          4773          3339           693           232
# 1220          1017          2357          1828           550           216
# 1230           611          1453           998           266           106
# 1240          2393          4611          3287           635           224
#
#       75to84_years  85Plus_years
# 1200           311           159
# 1210           195           108
# 1220           181           114
# 1230           109            84
# 1240           130            45

# %%
drug_2002_deaths = sorted_by_drug_deaths[sorted_by_drug_deaths['Year'] == 2002]
drug_2002_deaths.head()
# Out:
#       Year      Gender                                        Intent  \
# 1140  2002  Both sexes  All (preventable, intentional, undetermined)
# 1150  2002  Both sexes                        Preventable/accidental
# 1160  2002      Female  All (preventable, intentional, undetermined)
# 1170  2002      Female                        Preventable/accidental
# 1180  2002        Male  All (preventable, intentional, undetermined)
#
#       Substance  Under1_year  1to4_Years  5to14_years  15to24_years  \
# 1140  All drugs           27          30           40          2095
# 1150  All drugs           18          18           17          1573
# 1160  All drugs            7          21           17           560
# 1170  All drugs            3          11            4           353
# 1180  All drugs           20           9           23          1535
#
#       25to34_years  35to44_years  45to54_years  55to64_years  65to74_years  \
# 1140          4125          8064          6466          1601           508
# 1150          2971          5746          4450           954           286
# 1160          1210          2864          2485           724           277
# 1170           774          1836          1493           373           142
# 1180          2915          5200          3981           877           231
#
#       75to84_years  85Plus_years
# 1140           359           193
# 1150           211           143
# 1160           203           119
# 1170           121            91
# 1180           156            74

# %%
drug_2003_deaths = sorted_by_drug_deaths[sorted_by_drug_deaths['Year'] == 2003]
drug_2003_deaths.head()
# Out:
#       Year      Gender                                        Intent  \
# 1080  2003  Both sexes  All (preventable, intentional, undetermined)
# 1090  2003  Both sexes                        Preventable/accidental
# 1100  2003      Female  All (preventable, intentional, undetermined)
# 1110  2003      Female                        Preventable/accidental
# 1120  2003        Male  All (preventable, intentional, undetermined)
#
#       Substance  Under1_year  1to4_Years  5to14_years  15to24_years  \
# 1080  All drugs           24          35           41          2491
# 1090  All drugs           16          26           27          1882
# 1100  All drugs            8          14           21           632
# 1110  All drugs            8          11           14           417
# 1120  All drugs           16          21           20          1859
#
#       25to34_years  35to44_years  45to54_years  55to64_years  65to74_years  \
# 1080          4488          8358          7325          1943           534
# 1090          3303          5962          5182          1225           312
# 1100          1382          3032          2800           886           287
# 1110           898          2008          1788           497           148
# 1120          3106          5326          4525          1057           247
#
#       75to84_years  85Plus_years
# 1080           353           183
# 1090           220           133
# 1100           204           119
# 1110           113            94
# 1120           149            64

# %%
drug_2004_deaths = sorted_by_drug_deaths[sorted_by_drug_deaths['Year'] == 2004]
drug_2004_deaths.head()
# Out:
#       Year      Gender                                        Intent  \
# 1020  2004  Both sexes  All (preventable, intentional, undetermined)
# 1030  2004  Both sexes                        Preventable/accidental
# 1040  2004      Female  All (preventable, intentional, undetermined)
# 1050  2004      Female                        Preventable/accidental
# 1060  2004        Male  All (preventable, intentional, undetermined)
#
#       Substance  Under1_year  1to4_Years  5to14_years  15to24_years  \
# 1020  All drugs           30          24           63          2751
# 1030  All drugs           10          11           29          2154
# 1040  All drugs           19           8           38           683
# 1050  All drugs            7           3           12           473
# 1060  All drugs           11          16           25          2068
#
#       25to34_years  35to44_years  45to54_years  55to64_years  65to74_years  \
# 1020          4680          8439          8040          2283           549
# 1030          3511          6208          5765          1452           334
# 1040          1411          3249          3184          1064           300
# 1050           945          2219          2058           611           170
# 1060          3269          5190          4856          1219           249
#
#       75to84_years  85Plus_years
# 1020           372           183
# 1030           233           122
# 1040           226           117
# 1050           138            83
# 1060           146            66

# %%
drug_2005_deaths = sorted_by_drug_deaths[sorted_by_drug_deaths['Year'] == 2005]
drug_2005_deaths.head()
# Out:
#       Year      Gender                                        Intent  \
# 960   2005  Both sexes  All (preventable, intentional, undetermined)
# 970   2005  Both sexes                        Preventable/accidental
# 980   2005      Female  All (preventable, intentional, undetermined)
# 990   2005      Female                        Preventable/accidental
# 1000  2005        Male  All (preventable, intentional, undetermined)
#
#       Substance  Under1_year  1to4_Years  5to14_years  15to24_years  \
# 960   All drugs           35          30           47          2918
# 970   All drugs           15          10           29          2355
# 980   All drugs           17           7           24           733
# 990   All drugs            8           2           13           515
# 1000  All drugs           18          23           23          2185
#
#       25to34_years  35to44_years  45to54_years  55to64_years  65to74_years  \
# 960           5340          8506          8968          2761           607
# 970           4260          6490          6697          1854           358
# 980           1654          3227          3572          1192           321
# 990           1169          2250          2392           703           177
# 1000          3686          5279          5396          1569           286
#
#       75to84_years  85Plus_years
# 960            402           194
# 970            243           132
# 980            223           119
# 990            127            80
# 1000           179            75

# %%
drug_2006_deaths = sorted_by_drug_deaths[sorted_by_drug_deaths['Year'] == 2006]
drug_2006_deaths.head()
# Out:
#      Year      Gender                                        Intent  \
# 900  2006  Both sexes  All (preventable, intentional, undetermined)
# 910  2006  Both sexes                        Preventable/accidental
# 920  2006      Female  All (preventable, intentional, undetermined)
# 930  2006      Female                        Preventable/accidental
# 940  2006        Male  All (preventable, intentional, undetermined)
#
#      Substance  Under1_year  1to4_Years  5to14_years  15to24_years  \
# 900  All drugs           44          36           57          3460
# 910  All drugs           12          16           37          2817
# 920  All drugs           21          16           24           820
# 930  All drugs            6           7           13           599
# 940  All drugs           23          20           33          2640
#
#      25to34_years  35to44_years  45to54_years  55to64_years  65to74_years  \
# 900          6346          9373         10421          3355           677
# 910          5115          7299          7978          2274           423
# 920          1863          3459          4099          1459           370
# 930          1345          2462          2886           865           216
# 940          4483          5914          6322          1896           307
#
#      75to84_years  85Plus_years
# 900           431           213
# 910           265           153
# 920           257           141
# 930           155           103
# 940           174            72

# %%
drug_2007_deaths = sorted_by_drug_deaths[sorted_by_drug_deaths['Year'] == 2007]
drug_2007_deaths.head()
# Out:
#      Year      Gender                                        Intent  \
# 840  2007  Both sexes  All (preventable, intentional, undetermined)
# 850  2007  Both sexes                        Preventable/accidental
# 860  2007      Female  All (preventable, intentional, undetermined)
# 870  2007      Female                        Preventable/accidental
# 880  2007        Male  All (preventable, intentional, undetermined)
#
#      Substance  Under1_year  1to4_Years  5to14_years  15to24_years  \
# 840  All drugs           33          44           74          3550
# 850  All drugs           13          21           53          2927
# 860  All drugs           15          23           32           883
# 870  All drugs            4          10           20           677
# 880  All drugs           18          21           42          2667
#
#      25to34_years  35to44_years  45to54_years  55to64_years  65to74_years  \
# 840          6663          9152         11012          4043           791
# 850          5418          7123          8394          2807           481
# 860          2001          3463          4696          1809           393
# 870          1474          2524          3322          1130           207
# 880          4662          5689          6316          2234           398
#
#      75to84_years  85Plus_years
# 840           418           226
# 850           267           152
# 860           248           148
# 870           155           106
# 880           170            78

# %%
# Print head()
rates_data_info.head()
# Out:
#    Year      Gender                                        Intent  \
# 0  2021  Both sexes  All (preventable, intentional, undetermined)
# 1  2021  Both sexes  All (preventable, intentional, undetermined)
# 2  2021  Both sexes  All (preventable, intentional, undetermined)
# 3  2021  Both sexes  All (preventable, intentional, undetermined)
# 4  2021  Both sexes  All (preventable, intentional, undetermined)
#
#          Substance Under1_year 1to4_Years 5to14_years 15to24_years  \
# 0        All drugs         2.1        0.8        17.2         52.9
# 1       Any Opioid         1.2        0.7        14.6         44.6
# 2  Benzodiazepines          NR         NR         2.6          6.7
# 3         Cannabis           0          0         0.3          0.7
# 4          Cocaine          NR        0.1         2.7         10.5
#
#   25to34_years 35to44_years 45to54_years 55to64_years 65to74_years  \
# 0           62         53.8          0.3         45.3         16.8
# 1         48.6         38.3          0.2         30.6         10.2
# 2          7.4          5.8           NR          4.7          1.8
# 3          0.7          0.5            0          0.4          0.1
# 4         13.9         14.1           NR         12.6          3.8
#
#   75to84_years 85Plus_years
# 0          4.9          4.3
# 1          1.9          1.4
# 2          0.6          0.7
# 3            0            0
# 4          0.5           NR

# %%
# If any data cleaning needs to be done via code, it can be written here

# If ages need to be converted to integers, do it here
