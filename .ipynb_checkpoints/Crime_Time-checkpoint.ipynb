# %% [markdown]
# # **Objective**: Our project will investigate drug poisoning and fatalities, particularly examining the increasing prevalence of fentanyl, a powerful synthetic opioid approved by the FDA for pain relief and anesthesia. We aim to analyze fentanyl data alongside other substances. We are presenting statistics on fatalities and poisonings categorized by age, gender, and zip code. Additionally, we seek to correlate zip codes with income levels to provide a comprehensive understanding of the impact of drug use on different socioeconomical levels. Our data was gathered from 1999 to 2021.

# %%
# Dependencies
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
from pathlib import Path
from scipy import stats
import hvplot.pandas
from pprint import pprint
import seaborn as sns
from IPython.display import display


# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="a2411fa7-aa55-46d9-aeea-f85b32872c45" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"d89a7d05-e374-457f-aec6-fe6809553738":{"version":"3.3.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"ca94351dea924f3c9d6a10a433001133","client_comm_id":"699b0d489d5e42cd8528927cad864c36"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"toggle_value1","properties":[{"name":"active_icons","kind":"Any","default":{"type":"map"}},{"name":"options","kind":"Any","default":{"type":"map","entries":[["favorite","heart"]]}},{"name":"value","kind":"Any","default":[]},{"name":"_reactions","kind":"Any","default":[]},{"name":"_base_url","kind":"Any","default":"https://tabler-icons.io/static/tabler-icons/icons/"}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"value","kind":"Any","default":null},{"name":"fill","kind":"Any","default":"none"}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{ ...
#   var render_items = [{"docid":"d89a7d05-e374-457f-aec6-fe6809553738","roots":{"p1002":"a2411fa7-aa55-46d9-aeea-f85b32872c45"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
import plotly.express as px
import ipywidgets as widgets
from ipywidgets import interact

# %%
# Python SQL toolkit and Object Relational Mapper - just to have
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect
import psycopg2

# %%
# create engine to PostgreSQL
#engine = create_engine("postgresql://crime_user:crimetime@localhost:5432/Crime_Time")
engine = create_engine("postgresql://postgres:Turtle07@localhost:5432/Crime_Time")
inspector = inspect(engine)

# %%
# Connection parameters
#hostname = 'localhost'
#port = '5432'
#database = 'Crime_Time'
#username = 'crime_user'
#password = 'crimetime'

# Establish connection
#conn = psycopg2.connect(
    #host=hostname,
    #port=port,
    #database=database,
    #user=username,
    #password=password
#)

# Perform database operations
# (e.g., execute SQL queries, fetch data, etc.)

# %%
# Close connection
#conn.close()

# %%
# reflect an existing database into a new model
Base = automap_base()

# reflect the tables
#Base.prepare(autoload_with=engine, schema= )
Base.prepare(engine, reflect=True, schema='Deaths')
Base.prepare(engine, reflect=True, schema='OK_Income')
Base.prepare(engine, reflect=True, schema='OK_Death_Rates_')
# Out:
# C:\Users\Amanda\AppData\Local\Temp\ipykernel_26032\4002289448.py:6: SADeprecationWarning: The AutomapBase.prepare.reflect parameter is deprecated and will be removed in a future release.  Reflection is enabled when AutomapBase.prepare.autoload_with is passed.
#   Base.prepare(engine, reflect=True, schema='Deaths')
# C:\Users\Amanda\AppData\Local\Temp\ipykernel_26032\4002289448.py:7: SADeprecationWarning: The AutomapBase.prepare.reflect parameter is deprecated and will be removed in a future release.  Reflection is enabled when AutomapBase.prepare.autoload_with is passed.
#   Base.prepare(engine, reflect=True, schema='OK_Income')
# C:\Users\Amanda\AppData\Local\Temp\ipykernel_26032\4002289448.py:8: SADeprecationWarning: The AutomapBase.prepare.reflect parameter is deprecated and will be removed in a future release.  Reflection is enabled when AutomapBase.prepare.autoload_with is passed.
#   Base.prepare(engine, reflect=True, schema='OK_Death_Rates_')

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
# Get table names
table_names = inspector.get_table_names()

# Display schema for each table
for table_name in table_names:
    print(f"Table: {table_name}")
    columns = inspector.get_columns(table_name)
    for column in columns:
        print(f"  Column: {column['name']}, Type: {column['type']}")
    print("\n")
# Out:
# Table: OK_Death_Rate_
#   Column: State, Type: VARCHAR(255)
#   Column: Drug_Type, Type: VARCHAR(255)
#   Column: County, Type: VARCHAR(255)
#   Column: County_Code, Type: INTEGER
#   Column: Five_Year_Age_Groups, Type: VARCHAR(255)
#   Column: Five_Year_Age_Groups_Code, Type: VARCHAR(255)
#   Column: Gender, Type: VARCHAR(255)
#   Column: Gender_Code, Type: VARCHAR(255)
#   Column: MCD_Drug_Alcohol_Induced_Cause, Type: VARCHAR(255)
#   Column: MCD_Drug_Alcohol_Induced_Cause_Code, Type: VARCHAR(255)
#   Column: Deaths, Type: INTEGER
#   Column: Population, Type: INTEGER
#   Column: Crude_Rate, Type: VARCHAR(255)
#
#
# Table: OK_Income
#   Column: County, Type: VARCHAR(255)
#   Column: 2010, Type: INTEGER
#   Column: 2011, Type: INTEGER
#   Column: 2012, Type: INTEGER
#   Column: 2013, Type: INTEGER
#   Column: 2014, Type: INTEGER
#   Column: 2015, Type: INTEGER
#   Column: 2016, Type: INTEGER
#   Column: 2017, Type: INTEGER
#   Column: 2018, Type: INTEGER
#   Column: 2019, Type: INTEGER
#   Column: 2020, Type: INTEGER
#   Column: 2021, Type: INTEGER
#
#
# Table: Deaths
#   Column: Year, Type: INTEGER
#   Column: Gender, Type: VARCHAR(255)
#   Column: Intent, Type: VARCHAR(255)
#   Column: Substance, Type: VARCHAR(255)
#   Column: Under1_year, Type: INTEGER
#   Column: 1to4_Years, Type: INTEGER
#   Column: 5to14_years, Type: INTEGER
#   Column: 15to24_years, Type: INTEGER
#   Column: 25to34_years, Type: INTEGER
#   Column: 35to44_years, Type: INTEGER
#   Column: 45to54_years, Type: INTEGER
#   Column: 55to64_years, Type: INTEGER
#   Column: 65to74_years, Type: INTEGER
#   Column: 75to84_years, Type: INTEGER
#   Column: 85Plus_years, Type: INTEGER

# %%
# Specify the table name
table_name = "Deaths"

# Read data from the table into a DataFrame
deaths_df = pd.read_sql_table(table_name, con=engine)

# Display the first few rows of the DataFrame
print("Deaths DataFrame:")
display(deaths_df.head())
# Out:
# Deaths DataFrame:
#    Year  Gender                                        Intent  \
# 0  2021  Female  All (preventable, intentional, undetermined)
# 1  2021  Female  All (preventable, intentional, undetermined)
# 2  2021  Female  All (preventable, intentional, undetermined)
# 3  2021  Female  All (preventable, intentional, undetermined)
# 4  2021  Female  All (preventable, intentional, undetermined)
#
#          Substance  Under1_year  1to4_Years  5to14_years  15to24_years  \
# 0        All drugs           35          59         2311          6709
# 1       Any Opioid           25          50         1866          5539
# 2  Benzodiazepines            0           0          329          1012
# 3         Cannabis            0           0           41            77
# 4          Cocaine            0           0          384          1402
#
#    25to34_years  35to44_years  45to54_years  55to64_years  65to74_years  \
# 0          7967          6912            59          6122          1718
# 1          6046          4757            33          4155          1008
# 2          1241          1097             0           986           299
# 3            78            65             0            41             5
# 4          1784          1614             0          1423           229
#
#    75to84_years  85Plus_years
# 0           357           148
# 1           123            51
# 2            57            29
# 3             0             0
# 4            14             0

# %%
#This dataset was gathered from 1999 to 2020
# Specify the table name
table_name = "OK_Death_Rate_"

# Read data from the table into a DataFrame
okdeath_df = pd.read_sql_table(table_name, con=engine)

# Display the first few rows of the DataFrame
print("Oklahoma Death Rate DataFrame:")
display(okdeath_df.head())
# Out:
# Oklahoma Death Rate DataFrame:
#       State   Drug_Type               County  County_Code  \
# 0  Oklahoma  Psychotism     Creek County, OK        40037
# 1  Oklahoma  Psychotism  Oklahoma County, OK        40109
# 2  Oklahoma  Psychotism  Oklahoma County, OK        40109
# 3  Oklahoma  Psychotism  Oklahoma County, OK        40109
# 4  Oklahoma  Psychotism  Oklahoma County, OK        40109
#
#   Five_Year_Age_Groups Five_Year_Age_Groups_Code  Gender Gender_Code  \
# 0          50-54 years                     50-54    Male           M
# 1          20-24 years                     20-24    Male           M
# 2          25-29 years                     25-29  Female           F
# 3          25-29 years                     25-29    Male           M
# 4          30-34 years                     30-34  Female           F
#
#               MCD_Drug_Alcohol_Induced_Cause  \
# 0  All other non-drug and non-alcohol causes
# 1  All other non-drug and non-alcohol causes
# 2  All other non-drug and non-alcohol causes
# 3  All other non-drug and non-alcohol causes
# 4  All other non-drug and non-alcohol causes
#
#   MCD_Drug_Alcohol_Induced_Cause_Code  Deaths  Population  Crude_Rate
# 0                                  O9      10       53170  Unreliable
# 1                                  O9      13      596556  Unreliable
# 2                                  O9      20      638038         3.1
# 3                                  O9      19      632848  Unreliable
# 4                                  O9      20      573032         3.5

# %%
# Specify the table name
table_name = "OK_Income"

# Read data from the table into a DataFrame
income_df = pd.read_sql_table(table_name, con=engine)

# Display the first few rows of the DataFrame
print("Oklahoma Income DataFrame:")
display(income_df.head())
# Out:
# Oklahoma Income DataFrame:
#          County   2010   2011   2012   2013   2014   2015   2016   2017  \
# 0  Oklahoma All  37157  39693  41903  43605  45882  44277  42052  43871
# 1        Adair   23392  24676  25681  26108  27230  29760  29778  31327
# 2      Alfalfa   32090  38738  44584  42344  48532  44624  36521  35592
# 3        Atoka   25481  26711  27698  28554  29916  29912  29873  30981
# 4       Beaver   39913  48952  52613  55957  58084  51395  46166  50646
#
#     2018   2019   2020   2021
# 0  46029  48172  50249  55165
# 1  31975  33062  35788  40275
# 2  39211  38040  40934  45533
# 3  31467  32234  34422  36277
# 4  54786  55866  58018  68300

# %% [markdown]
# ## Average income per county vs Overdose deaths per county in Oklahoma

# %%
# Print column names of okdeath_df and income_df to check headers
print("Columns of okdeath_df:")
print(okdeath_df.columns)

print("\nColumns of income_df:")
print(income_df.columns)
# Out:
# Columns of okdeath_df:
# Index(['State', 'Drug_Type', 'County', 'County_Code', 'Five_Year_Age_Groups',
#        'Five_Year_Age_Groups_Code', 'Gender', 'Gender_Code',
#        'MCD_Drug_Alcohol_Induced_Cause', 'MCD_Drug_Alcohol_Induced_Cause_Code',
#        'Deaths', 'Population', 'Crude_Rate'],
#       dtype='object')
#
# Columns of income_df:
# Index(['County', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
# Merge the two dataframes on the 'County' column
economicsbycounty_df = pd.merge(sorted_ok, income_df, on='County', how='outer')
# Display the merged dataframe
economicsbycounty_df.head()
# Out:
#       State      Drug_Type                County  County_Code  \
# 0  Oklahoma  Other Opioids   Canadian County, OK      40017.0
# 1  Oklahoma  Other Opioids   Canadian County, OK      40017.0
# 2  Oklahoma          Benzo  Cleveland County, OK      40027.0
# 3  Oklahoma          Benzo  Cleveland County, OK      40027.0
# 4  Oklahoma         Heroin  Cleveland County, OK      40027.0
#
#   Five_Year_Age_Groups Five_Year_Age_Groups_Code  Gender Gender_Code  \
# 0          40-44 years                     40-44  Female           F
# 1          45-49 years                     45-49    Male           M
# 2          20-24 years                     20-24    Male           M
# 3          25-29 years                     25-29    Male           M
# 4          20-24 years                     20-24    Male           M
#
#               MCD_Drug_Alcohol_Induced_Cause  \
# 0  All other non-drug and non-alcohol causes
# 1  All other non-drug and non-alcohol causes
# 2  All other non-drug and non-alcohol causes
# 3  All other non-drug and non-alcohol causes
# 4  All other non-drug and non-alcohol causes
#
#   MCD_Drug_Alcohol_Induced_Cause_Code  ...  2012  2013 2014  2015  2016  2017  \
# 0                                  O9  ...   NaN   NaN  NaN   NaN   NaN   NaN
# 1                                  O9  ...   NaN   NaN  NaN   NaN   NaN   NaN
# 2                                  O9  ...   NaN   NaN  NaN   NaN   NaN   NaN
# 3                                  O9  ...   NaN   NaN  NaN   NaN   NaN   NaN
# 4                                  O9  ...   NaN   NaN  NaN   NaN   NaN   NaN
#
#    2018  2019  2020  2021
# 0   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Three Table Merge

# %%
#combined DF may not be needed, but here it is anyway

# Create a dictionary to store column names
column_names_reference = {}

# Get table names
table_names = inspector.get_table_names()

# Create an empty DataFrame to store the data
all_data_df = pd.DataFrame()

# Populate the dictionary with column names and retrieve data for each table
for table_name in table_names:
    columns = inspector.get_columns(table_name)
    column_names = [column['name'] for column in columns]
    column_names_reference[table_name] = column_names

    # Read data from the table into a DataFrame
    table_data_df = pd.read_sql_table(table_name, con=engine)

    # Append the table data to the main DataFrame
    all_data_df = pd.concat([all_data_df, table_data_df], ignore_index=True)


# Display the column names reference
print("Column Names Reference:")
for table_name, columns in column_names_reference.items():
    print(f"Table: {table_name}, Columns: {columns}")

# Display the first few rows of the combined DataFrame
print("\nCombined DataFrame:")
display(all_data_df.head())

# %%
# Specify the column order for sorting
sort_columns = ['Year', 'Substance', 'Gender']

# Sort the DataFrame by the specified columns
sorted_deaths = deaths_df.sort_values(by=sort_columns)

# Display the sorted DataFrame
print("Sorted Deaths DataFrame:")
display(sorted_deaths)

# %% [markdown]
# ## Deaths by Year

# %%
# Specify the year you want to filter
target_year = 1999

# Filter the 'Deaths' DataFrame for the specified year
deaths_1999 = sorted_deaths[sorted_deaths['Year'] == target_year]

# Display the DataFrame containing deaths in the year 1999
print(f"Deaths in the Year {target_year}:\n")
display(deaths_1999)

# %%
# Specify the year you want to filter
target_year = 2000

# Filter the 'Deaths' DataFrame for the specified year
deaths_2000 = sorted_deaths[sorted_deaths['Year'] == target_year]

# Display the DataFrame containing deaths in the year 2000
print(f"Deaths in the Year {target_year}:\n")
display(deaths_2000)

# %%
# Specify the year you want to filter
target_year = 2001

# Filter the 'Deaths' DataFrame for the specified year
deaths_2001 = sorted_deaths[sorted_deaths['Year'] == target_year]

# Display the DataFrame containing deaths in the year 2001
print(f"Deaths in the Year {target_year}:\n")
display(deaths_2001)

# %%
# Specify the year you want to filter
target_year = 2002

# Filter the 'Deaths' DataFrame for the specified year
deaths_2002 = sorted_deaths[sorted_deaths['Year'] == target_year]

# Display the DataFrame containing deaths in the year 2002
print(f"Deaths in the Year {target_year}:\n")
display(deaths_2002)

# %%
# Specify the year you want to filter
target_year = 2003

# Filter the 'Deaths' DataFrame for the specified year
deaths_2003 = sorted_deaths[sorted_deaths['Year'] == target_year]

# Display the DataFrame containing deaths in the year 2003
print(f"Deaths in the Year {target_year}:\n")
display(deaths_2003)

# %%
# Specify the year you want to filter
target_year = 2004

# Filter the 'Deaths' DataFrame for the specified year
deaths_2004 = sorted_deaths[sorted_deaths['Year'] == target_year]

# Display the DataFrame containing deaths in the year 2004
print(f"Deaths in the Year {target_year}:\n")
display(deaths_2004)

# %%
# Specify the year you want to filter
target_year = 2005

# Filter the 'Deaths' DataFrame for the specified year
deaths_2005 = sorted_deaths[sorted_deaths['Year'] == target_year]

# Display the DataFrame containing deaths in the year 2005
print(f"Deaths in the Year {target_year}:\n")
display(deaths_2005)

# %%
# Specify the year you want to filter
target_year = 2006

# Filter the 'Deaths' DataFrame for the specified year
deaths_2006 = sorted_deaths[sorted_deaths['Year'] == target_year]

# Display the DataFrame containing deaths in the year 2006
print(f"Deaths in the Year {target_year}:\n")
display(deaths_2006)

# %%
# Specify the year you want to filter
target_year = 2007

# Filter the 'Deaths' DataFrame for the specified year
deaths_2007 = sorted_deaths[sorted_deaths['Year'] == target_year]

# Display the DataFrame containing deaths in the year 2007
print(f"Deaths in the Year {target_year}:\n")
display(deaths_2007)

# %%
# Specify the year you want to filter
target_year = 2008

# Filter the 'Deaths' DataFrame for the specified year
deaths_2008 = sorted_deaths[sorted_deaths['Year'] == target_year]

# Display the DataFrame containing deaths in the year 2008
print(f"Deaths in the Year {target_year}:\n")
display(deaths_2008)

# %%
# Specify the year you want to filter
target_year = 2009

# Filter the 'Deaths' DataFrame for the specified year
deaths_2009 = sorted_deaths[sorted_deaths['Year'] == target_year]

# Display the DataFrame containing deaths in the year 2009
print(f"Deaths in the Year {target_year}:\n")
display(deaths_2009)

# %%
# Specify the year you want to filter
target_year = 2010

# Filter the 'Deaths' DataFrame for the specified year
deaths_2010 = sorted_deaths[sorted_deaths['Year'] == target_year]

# Display the DataFrame containing deaths in the year 2010
print(f"Deaths in the Year {target_year}:\n")
display(deaths_2010)

# %%
# Specify the year you want to filter
target_year = 2011

# Filter the 'Deaths' DataFrame for the specified year
deaths_2011 = sorted_deaths[sorted_deaths['Year'] == target_year]

# Display the DataFrame containing deaths in the year 2011
print(f"Deaths in the Year {target_year}:\n")
display(deaths_2011)

# %%
# Specify the year you want to filter
target_year = 2012

# Filter the 'Deaths' DataFrame for the specified year
deaths_2012 = sorted_deaths[sorted_deaths['Year'] == target_year]

# Display the DataFrame containing deaths in the year 2012
print(f"Deaths in the Year {target_year}:\n")
display(deaths_2012)

# %%
# Specify the year you want to filter
target_year = 2013

# Filter the 'Deaths' DataFrame for the specified year
deaths_2013 = sorted_deaths[sorted_deaths['Year'] == target_year]

# Display the DataFrame containing deaths in the year 2013
print(f"Deaths in the Year {target_year}:\n")
display(deaths_2013)

# %%
# Specify the year you want to filter
target_year = 2014

# Filter the 'Deaths' DataFrame for the specified year
deaths_2014 = sorted_deaths[sorted_deaths['Year'] == target_year]

# Display the DataFrame containing deaths in the year 2014
print(f"Deaths in the Year {target_year}:\n")
display(deaths_2014)

# %%
# Specify the year you want to filter
target_year = 2015

# Filter the 'Deaths' DataFrame for the specified year
deaths_2015 = sorted_deaths[sorted_deaths['Year'] == target_year]

# Display the DataFrame containing deaths in the year 2015
print(f"Deaths in the Year {target_year}:\n")
display(deaths_2015)

# %%
# Specify the year you want to filter
target_year = 2016

# Filter the 'Deaths' DataFrame for the specified year
deaths_2016 = sorted_deaths[sorted_deaths['Year'] == target_year]

# Display the DataFrame containing deaths in the year 2016
print(f"Deaths in the Year {target_year}:\n")
display(deaths_2016)

# %%
# Specify the year you want to filter
target_year = 2017

# Filter the 'Deaths' DataFrame for the specified year
deaths_2017 = sorted_deaths[sorted_deaths['Year'] == target_year]

# Display the DataFrame containing deaths in the year 2017
print(f"Deaths in the Year {target_year}:\n")
display(deaths_2017)

# %%
# Specify the year you want to filter
target_year = 2018

# Filter the 'Deaths' DataFrame for the specified year
deaths_2018 = sorted_deaths[sorted_deaths['Year'] == target_year]

# Display the DataFrame containing deaths in the year 2018
print(f"Deaths in the Year {target_year}:\n")
display(deaths_2018)

# %%
# Specify the year you want to filter
target_year = 2019

# Filter the 'Deaths' DataFrame for the specified year
deaths_2019 = sorted_deaths[sorted_deaths['Year'] == target_year]

# Display the DataFrame containing deaths in the year 2019
print(f"Deaths in the Year {target_year}:\n")
display(deaths_2019)

# %%
# Specify the year you want to filter
target_year = 2020

# Filter the 'Deaths' DataFrame for the specified year
deaths_2020 = sorted_deaths[sorted_deaths['Year'] == target_year]

# Display the DataFrame containing deaths in the year 2020
print(f"Deaths in the Year {target_year}:\n")
display(deaths_2020)

# %%
# Specify the year you want to filter
target_year = 2021

# Filter the 'Deaths' DataFrame for the specified year
deaths_2021 = sorted_deaths[sorted_deaths['Year'] == target_year]

# Display the DataFrame containing deaths in the year 2021
print(f"Deaths in the Year {target_year}:\n")
display(deaths_2021)

# %% [markdown]
# ## Deaths by Year and Substance Visualization

# %%
#import plotly.express as px
# from ipywidgets import interact, widgets

# Create dropdown widgets for selecting the year and substance
year_dropdown = widgets.Dropdown(options=sorted_deaths['Year'].unique(), description='Select Year')
substance_dropdown = widgets.Dropdown(options=sorted_deaths['Substance'].unique(), description='Select Substance')

# Function to update the chart based on the selected year and substance
def update_chart(selected_year, selected_substance):
    filtered_data = sorted_deaths[(sorted_deaths['Year'] == selected_year) & (sorted_deaths['Substance'] == selected_substance)]
    
    # Extract relevant columns for plotting
    data_for_plotting = filtered_data[['Substance', 'Under1_year', '1to4_Years', '5to14_years',
                                       '15to24_years', '25to34_years', '35to44_years', '45to54_years',
                                       '55to64_years', '65to74_years', '75to84_years', '85Plus_years']]
    
    # Melt the DataFrame to 'long' format for Plotly plotting
    melted_data = data_for_plotting.melt(id_vars='Substance', var_name='Age_Group', value_name='Number_of_Deaths')

    # Create an interactive bar chart using Plotly
    fig = px.bar(melted_data, x='Substance', y='Number_of_Deaths', color='Age_Group',
                 labels={'Number_of_Deaths': 'Number of Deaths'},
                 title=f'Bar Chart of Deaths for {selected_year} - Substance: {selected_substance}',
                 barmode='group')
    
    # Show the chart
    fig.show(renderer="notebook")

# Connect the dropdown widgets to the update function
interact(update_chart, selected_year=year_dropdown, selected_substance=substance_dropdown);

# %% [markdown]
# ## Fentanyl Over Time

# %%
#import seaborn as sns
#import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'filtered_data'
# Replace these column names with your actual column names

# Sample data creation
#import pandas as pd
#import numpy as np

# Set option to handle inf values
pd.set_option('mode.use_inf_as_na', True)

# Assuming you have a DataFrame named 'filtered_data'
# Replace these column names with your actual column names

# Filter the data for the specific substance
opioid_data = sorted_deaths[sorted_deaths["Substance"] == "Opioid subgroup – including fentanyl"]

# Sum deaths across all age groups for each year
total_deaths_per_year = opioid_data.groupby("Year").sum(numeric_only=True).sum(axis=1).reset_index()
total_deaths_per_year.columns = ["Year", "Total_Deaths"]

# Plotting using Seaborn with warnings suppressed
plt.figure(figsize=(12, 6))
with sns.plotting_context(context="notebook", rc={"axes.labelsize": 14}), sns.axes_style("whitegrid"):
    sns.lineplot(x="Year", y="Total_Deaths", data=total_deaths_per_year, marker="o", estimator=None)
    plt.xticks(total_deaths_per_year["Year"])  # Set x-ticks to include all years
plt.title("Total Deaths per Year for Opioid Subgroup – including fentanyl")
plt.xlabel("Year")
plt.ylabel("Total Deaths")
plt.show()

# %% [markdown]
# ## PsychoStimulants (Meth) Over Time

# %%
# Set option to handle inf values
pd.set_option('mode.use_inf_as_na', True)

# Filter the data for the specific substance
psychostimulant_data = sorted_deaths[sorted_deaths["Substance"] == "Psychostimulants – incl. methamphetamine"]

# Sum deaths across all age groups for each year
total_deaths_per_year = psychostimulant_data.groupby("Year").sum(numeric_only=True).sum(axis=1).reset_index()
total_deaths_per_year.columns = ["Year", "Total_Deaths"]

# Plotting using Seaborn with warnings suppressed
plt.figure(figsize=(12, 6))
with sns.plotting_context(context="notebook", rc={"axes.labelsize": 14}), sns.axes_style("whitegrid"):
    sns.lineplot(x="Year", y="Total_Deaths", data=total_deaths_per_year, marker="o", estimator=None)
    plt.xticks(total_deaths_per_year["Year"])  # Set x-ticks to include all years
plt.title("Total Deaths per Year for Psychostimulants – incl. methamphetamine")
plt.xlabel("Year")
plt.ylabel("Total Deaths")
plt.show()

# %%
# Assuming you have a DataFrame named 'sorted_deaths'
# Set option to handle inf values
pd.set_option('mode.use_inf_as_na', True)

# Filter the data for the specific substances
opioid_data = sorted_deaths[sorted_deaths["Substance"] == "Opioid subgroup – including fentanyl"]
psychostimulant_data = sorted_deaths[sorted_deaths["Substance"] == "Psychostimulants – incl. methamphetamine"]

# Combine the data for both substances
combined_data = pd.concat([opioid_data, psychostimulant_data])

# Sum deaths across age groups for each row and create a new column 'Total_Deaths'
combined_data['Total_Deaths'] = combined_data[[
    "Under1_year", "1to4_Years", "5to14_years", "15to24_years", 
    "25to34_years", "35to44_years", "45to54_years", "55to64_years", 
    "65to74_years", "75to84_years", "85Plus_years"
]].sum(axis=1)

# Create a relational plot using sns.relplot
plt.figure(figsize=(12, 6))
with sns.plotting_context(context="notebook", rc={"axes.labelsize": 14}), sns.axes_style("whitegrid"):
    sns.relplot(x="Year", y="Total_Deaths", hue="Substance", kind="line", data=combined_data)
plt.title("Comparison of Deaths over Time for Opioid and Psychostimulant Substances")
plt.xlabel("Year")
plt.ylabel("Total Deaths")
plt.show()

# %% [markdown]
# # Data Clean Up - Oklahoma

# %%
#Dataset gathered from 1999 to 2020
# Specify the column order for sorting
sort_columns = ['County', 'Drug_Type', 'Gender']

# Sort the DataFrame by the specified columns
sorted_ok = okdeath_df.sort_values(by=sort_columns)

# Display the sorted DataFrame
print("Sorted Oklahoma Death Rates DataFrame:")
display(sorted_ok)
# Out:
# Sorted Oklahoma Death Rates DataFrame:
#         State      Drug_Type                County  County_Code  \
# 108  Oklahoma  Other Opioids   Canadian County, OK        40017
# 109  Oklahoma  Other Opioids   Canadian County, OK        40017
# 61   Oklahoma          Benzo  Cleveland County, OK        40027
# 62   Oklahoma          Benzo  Cleveland County, OK        40027
# 95   Oklahoma         Heroin  Cleveland County, OK        40027
# ..        ...            ...                   ...          ...
# 35   Oklahoma     Psychotism      Tulsa County, OK        40143
# 176  Oklahoma  Other Opioids    Wagoner County, OK        40145
# 177  Oklahoma  Other Opioids    Wagoner County, OK        40145
# 174  Oklahoma  Other Opioids    Wagoner County, OK        40145
# 175  Oklahoma  Other Opioids    Wagoner County, OK        40145
#
#     Five_Year_Age_Groups Five_Year_Age_Groups_Code  Gender Gender_Code  \
# 108          40-44 years                     40-44  Female           F
# 109          45-49 years                     45-49    Male           M
# 61           20-24 years                     20-24    Male           M
# 62           25-29 years                     25-29    Male           M
# 95           20-24 years                     20-24    Male           M
# ..                   ...                       ...     ...         ...
# 35          60-64 years                      60-64    Male           M
# 176          45-49 years                     45-49  Female           F
# 177          50-54 years                     50-54  Female           F
# 174          20-24 years                     20-24    Male           M
# 175          35-39 years                     35-39    Male           M
#
#                 MCD_Drug_Alcohol_Induced_Cause  \
# 108  All other non-drug and non-alcohol causes
# 109  All other non-drug and non-alcohol causes
# 61   All other non-drug and non-alcohol causes
# 62   All other non-drug and non-alcohol causes
# 95   All other non-drug and non-alcohol causes
# ..                                         ...
# 35   All other non-drug and non-alcohol causes
# 176  All other non-drug and non-alcohol causes
# 177  All other non-drug and non-alcohol causes
# 174  All other non-drug and non-alcohol causes
# 175  All other non-drug and non-alcohol causes
#
#     MCD_Drug_Alcohol_Induced_Cause_Code  Deaths  Population  Crude_Rate
# 108                                  O9      10       93323  Unreliable
# 109                                  O9      10       91308  Unreliable
# 61                                   O9      11      319838  Unreliable
# 62                                   O9      12      219961  Unreliable
# 95                                   O9      12      319838  Unreliable
# ..                                  ...     ...         ...         ...
# 35                                   O9      21      306029         6.9
# 176                                  O9      13       54922  Unreliable
# 177                                  O9      10       54848  Unreliable
# 174                                  O9      10       41069  Unreliable
# 175                                  O9      11       53632  Unreliable
#
# [234 rows x 13 columns]

# %% [markdown]
# ## Drug Deaths by County

# %%
# import plotly.express as px
#from ipywidgets import interact, widgets

# Create dropdown widgets for selecting the county and drug type
county_dropdown = widgets.Dropdown(options=sorted_ok['County'].unique(), description='Select County')
drug_type_dropdown = widgets.Dropdown(options=sorted_ok['Drug_Type'].unique(), description='Select Drug Type')

# Function to update the chart based on the selected county and drug type
def update_chart(selected_county, selected_drug_type):
    filtered_data = sorted_ok[
        (sorted_ok['County'] == selected_county) & 
        (sorted_ok['Drug_Type'] == selected_drug_type)
    ]
    
    # Check if there is data for the selected combination
    if filtered_data.empty:
        print(f'No results for {selected_county} - {selected_drug_type}')
        return
    
    # Extract relevant columns for plotting
    data_for_plotting = filtered_data[['Five_Year_Age_Groups', 'Deaths', 'Gender']]
    
    # Create an interactive bar chart using Plotly
    fig = px.bar(data_for_plotting, x='Five_Year_Age_Groups', y='Deaths',
                 color='Gender',
                 labels={'Deaths': 'Number of Deaths'},
                 title=f'Bar Chart of Deaths for {selected_county} - Drug Type: {selected_drug_type} by Gender')
    
    # Show the chart
    fig.show(renderer="notebook")

# Connect the dropdown widgets to the update function
interact(update_chart, selected_county=county_dropdown, selected_drug_type=drug_type_dropdown);
# Out:
# interactive(children=(Dropdown(description='Select County', options=('Canadian County, OK', 'Cleveland County,…

# %%
# Calculate the total deaths for each year
sorted_deaths['Total_Deaths'] = sorted_deaths.iloc[:, 4:].sum(axis=1)

# Pivot the DataFrame for seaborn heatmap
heatmap_data = sorted_deaths.pivot_table(index='Year', values='Total_Deaths', aggfunc='sum')

# Create the heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(heatmap_data, cmap='YlGnBu', annot=True, fmt='g', cbar_kws={'label': 'Total Deaths'})
plt.title('Heatmap of Total Deaths Across Age Categories Over the Years')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 2
#       1 # Calculate the total deaths for each year
# ----> 2 sorted_deaths['Total_Deaths'] = sorted_deaths.iloc[:, 4:].sum(axis=1)
#       4 # Pivot the DataFrame for seaborn heatmap
#       5 heatmap_data = sorted_deaths.pivot_table(index='Year', values='Total_Deaths', aggfunc='sum')
#
# NameError: name 'sorted_deaths' is not defined

# %%
import warnings

# Calculate the total deaths for each year
sorted_deaths['Total_Deaths'] = sorted_deaths.iloc[:, 4:].sum(axis=1)

# Suppress FutureWarning
with warnings.catch_warnings():
    warnings.filterwarnings("ignore", category=FutureWarning)

    # Create a Violin Plot
    plt.figure(figsize=(16, 8))
    sns.violinplot(x='Year', y='Total_Deaths', data=sorted_deaths)
    plt.title('Total Deaths Across Age Categories Over the Years')
    plt.xlabel('Year')
    plt.ylabel('Total Deaths')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 4
#       1 import warnings
#       3 # Calculate the total deaths for each year
# ----> 4 sorted_deaths['Total_Deaths'] = sorted_deaths.iloc[:, 4:].sum(axis=1)
#       6 # Suppress FutureWarning
#       7 with warnings.catch_warnings():
#
# NameError: name 'sorted_deaths' is not defined

# %%
# Calculate the total deaths for each year
sorted_deaths['Total_Deaths'] = sorted_deaths.iloc[:, 4:].sum(axis=1)

# Create a Treemap
fig = px.treemap(sorted_deaths, path=['Year', 'Total_Deaths'], values='Total_Deaths',
                 color='Total_Deaths', hover_data=['Year'])
fig.update_layout(title='Total Deaths Across Age Categories Over the Years')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 2
#       1 # Calculate the total deaths for each year
# ----> 2 sorted_deaths['Total_Deaths'] = sorted_deaths.iloc[:, 4:].sum(axis=1)
#       4 # Create a Treemap
#       5 fig = px.treemap(sorted_deaths, path=['Year', 'Total_Deaths'], values='Total_Deaths',
#       6                  color='Total_Deaths', hover_data=['Year'])
#
# NameError: name 'sorted_deaths' is not defined

# %% [markdown]
# # App Creation

# %% [markdown]
# ## Map By County

# %%
import json
import folium
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[52], line 2
#       1 import json
# ----> 2 import folium
#       3 import geopandas as gpd
#
# ModuleNotFoundError: No module named 'folium'

# %%
# Load the Shapefile into a GeoDataFrame
shapefile_path = 'GitHub\Project3-CrimeData\Resources\COUNTY_BOUNDARY.shp'
gdf = gpd.read_file(shapefile_path)

# Create a Folium map centered on Oklahoma
m = folium.Map(location=[35.5, -97.5], zoom_start=7)

# Add the GeoDataFrame to the map
folium.GeoJson(gdf).add_to(m)

# Display the map
m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 3
#       1 # Load the Shapefile into a GeoDataFrame
#       2 shapefile_path = 'GitHub\Project3-CrimeData\Resources\COUNTY_BOUNDARY.shp'
# ----> 3 gdf = gpd.read_file(shapefile_path)
#       5 # Create a Folium map centered on Oklahoma
#       6 m = folium.Map(location=[35.5, -97.5], zoom_start=7)
#
# NameError: name 'gpd' is not defined

# %%
# Select relevant columns for correlation
correlation_data = economicsbycounty_df[['Crude_Rate', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']]

# Convert columns to numeric, replacing non-convertible values with NaN
correlation_data_numeric = correlation_data.apply(pd.to_numeric, errors='coerce')

# Calculate correlation matrix
correlation_matrix = correlation_data_numeric.corr()

# Plot heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning:
#
# Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior

# %%
# Select relevant columns for the pair plot
pair_plot_data = economicsbycounty_df[['Crude_Rate', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']]

# Convert columns to numeric, replacing non-convertible values with NaN
pair_plot_data_numeric = pair_plot_data.apply(pd.to_numeric, errors='coerce')

# Combine 'Crude_Rate' with income columns
pair_plot_data_numeric['Crude_Rate'] = economicsbycounty_df['Crude_Rate']

# Create a pair plot
sns.pairplot(pair_plot_data_numeric, diag_kind='kde')
plt.suptitle('Pair Plot: Crude Rate and Income Variables', y=1.02)
plt.show()
# Out:
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %%
# Aggregate total deaths by county
total_deaths_by_county = economicsbycounty_df.groupby('County')['Deaths'].sum().reset_index()

# Set up the figure and subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10), gridspec_kw={'height_ratios': [2, 1]})

# Subplot 1: Bar plot for total deaths
sns.barplot(x='County', y='Deaths', data=total_deaths_by_county, color='skyblue', ax=ax1)
ax1.set_ylabel('Total Deaths', color='skyblue')
ax1.tick_params('y', colors='skyblue')

# Subplot 2: Line plot for economic data (e.g., 2020 income)
sns.lineplot(x='County', y='2020', data=economicsbycounty_df, color='red', ax=ax2)
ax2.set_ylabel('Economic Data (e.g., 2020 Income)', color='red')
ax2.tick_params('y', colors='red')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.suptitle('Total Deaths and Economic Data by County', y=1.02)
plt.show()
# Out:
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.

# %%
# Filter the data for Oklahoma
oklahoma_deaths = economicsbycounty_df[economicsbycounty_df['State'] == 'Oklahoma']

# Aggregate total deaths by county
total_deaths_by_county = oklahoma_deaths.groupby('County')['Deaths'].sum().reset_index()

# Create a pie chart
plt.figure(figsize=(10, 8))
plt.pie(total_deaths_by_county['Deaths'], labels=None, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)

# Add a legend outside the pie chart with adjusted layout
plt.legend(total_deaths_by_county['County'], loc='center left', bbox_to_anchor=(1, 0.5))

plt.title('Total Deaths by County in Oklahoma')
plt.show()

# %%
# Filter the data for Oklahoma
oklahoma_deaths = economicsbycounty_df[economicsbycounty_df['State'] == 'Oklahoma']

# Aggregate total deaths by county
total_deaths_by_county = oklahoma_deaths.groupby('County')['Deaths'].sum().reset_index()

# Calculate the total number of deaths
total_deaths = total_deaths_by_county['Deaths'].sum()

# Create a pie chart
plt.figure(figsize=(10, 8))
plt.pie(total_deaths_by_county['Deaths'], labels=None, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)

# Add a legend outside the pie chart with adjusted layout
plt.legend(total_deaths_by_county['County'], loc='center left', bbox_to_anchor=(1, 0.5))

# Add a text annotation for the total number of deaths in the upper right corner
plt.text(1.25, 1, f'Total Deaths\n{total_deaths}', ha='right', va='top', fontsize=14, bbox=dict(boxstyle='round', facecolor='white'))

plt.title('Total Deaths by County in Oklahoma')
plt.show()

# %%
# Select relevant columns for the correlation
correlation_data = economicsbycounty_df[['County', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', 'Deaths']]

# Convert income columns to numeric, replacing non-convertible values with NaN
correlation_data_numeric = correlation_data.iloc[:, 1:-1].apply(pd.to_numeric, errors='coerce')

# Calculate average income across years for each county
correlation_data_numeric['Average_Income'] = correlation_data_numeric.mean(axis=1)

# Calculate correlation between average income and deaths
correlation = correlation_data_numeric['Average_Income'].corr(correlation_data_numeric['Deaths'])

# Print correlation coefficient
print(f"Correlation between Average Income and Total Deaths per County: {correlation:.2f}")

# Plot scatterplot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Average_Income', y='Deaths', data=correlation_data_numeric)
plt.title('Scatter Plot: Average Income vs. Total Deaths per County')
plt.xlabel('Average Income')
plt.ylabel('Total Deaths')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Deaths'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 11
#       8 correlation_data_numeric['Average_Income'] = correlation_data_numeric.mean(axis=1)
#      10 # Calculate correlation between average income and deaths
# ---> 11 correlation = correlation_data_numeric['Average_Income'].corr(correlation_data_numeric['Deaths'])
#      13 # Print correlation coefficient
#      14 print(f"Correlation between Average Income and Total Deaths per County: {correlation:.2f}")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'Deaths'

# %%
print(economicsbycounty_df.dtypes)
# Out:
# State                                   object
# Drug_Type                               object
# County                                  object
# County_Code                            float64
# Five_Year_Age_Groups                    object
# Five_Year_Age_Groups_Code               object
# Gender                                  object
# Gender_Code                             object
# MCD_Drug_Alcohol_Induced_Cause          object
# MCD_Drug_Alcohol_Induced_Cause_Code     object
# Deaths                                 float64
# Population                             float64
# Crude_Rate                              object
# 2010                                   float64
# 2011                                   float64
# 2012                                   float64
# 2013                                   float64
# 2014                                   float64
# 2015                                   float64
# 2016                                   float64
# 2017                                   float64
# 2018                                   float64
# 2019                                   float64
# 2020                                   float64
# 2021                                   float64
# dtype: object

# %%
# Suppress FutureWarning about is_categorical_dtype
with warnings.catch_warnings():
    warnings.filterwarnings("ignore", category=FutureWarning)

    # Select relevant columns for the correlation
    correlation_data = economicsbycounty_df[['County', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', 'Deaths']]

    # Convert income columns to numeric, replacing non-convertible values with NaN
    correlation_data_numeric = correlation_data.iloc[:, 1:-1].apply(pd.to_numeric, errors='coerce')

    # Convert 'Deaths' column to numeric
    correlation_data_numeric['Deaths'] = pd.to_numeric(correlation_data['Deaths'], errors='coerce')

    # Drop rows where 'Deaths' is NaN
    correlation_data_numeric = correlation_data_numeric.dropna(subset=['Deaths'])

    # Calculate average income across years for each county
    correlation_data_numeric['Average_Income'] = correlation_data_numeric.mean(axis=1)

    # Calculate correlation between average income and deaths
    correlation = correlation_data_numeric['Average_Income'].corr(correlation_data_numeric['Deaths'])

# Print correlation coefficient
print(f"Correlation between Average Income and Total Deaths per County: {correlation:.2f}")

# Plot scatterplot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Average_Income', y='Deaths', data=correlation_data_numeric)
plt.title('Scatter Plot: Average Income vs. Total Deaths per County')
plt.xlabel('Average Income')
plt.ylabel('Total Deaths')
plt.show()
# Out:
# Correlation between Average Income and Total Deaths per County: 1.00
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %%
# Scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Average_Income', y='Deaths', data=correlation_data_numeric)
plt.title('Scatter Plot: Average Income vs. Total Deaths per County')
plt.xlabel('Average Income')
plt.ylabel('Total Deaths')
plt.show()
# Out:
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %%
# Scatter plot with county labels
plt.figure(figsize=(12, 8))
scatter = sns.scatterplot(x='Average_Income', y='Deaths', data=correlation_data_numeric)

# Add county labels
for line in range(0, correlation_data_numeric.shape[0]):
    plt.text(correlation_data_numeric['Average_Income'].iloc[line],
             correlation_data_numeric['Deaths'].iloc[line],
             correlation_data_numeric['County'].iloc[line],
             horizontalalignment='right',
             size='small', color='black', alpha=0.7)

plt.title('Scatter Plot: Average Income vs. Total Deaths per County')
plt.xlabel('Average Income')
plt.ylabel('Total Deaths')
plt.show()
# Out:
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\Amanda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'County'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 9
#       5 # Add county labels
#       6 for line in range(0, correlation_data_numeric.shape[0]):
#       7     plt.text(correlation_data_numeric['Average_Income'].iloc[line],
#       8              correlation_data_numeric['Deaths'].iloc[line],
# ----> 9              correlation_data_numeric['County'].iloc[line],
#      10              horizontalalignment='right',
#      11              size='small', color='black', alpha=0.7)
#      13 plt.title('Scatter Plot: Average Income vs. Total Deaths per County')
#      14 plt.xlabel('Average Income')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'County'

# %%
import matplotlib.pyplot as plt

# Filter the data for Oklahoma
oklahoma_deaths = economicsbycounty_df[economicsbycounty_df['State'] == 'Oklahoma']

# Aggregate total deaths by county
total_deaths_by_county = oklahoma_deaths.groupby('County')['Deaths'].sum().reset_index()

# Calculate the total number of deaths
total_deaths = total_deaths_by_county['Deaths'].sum()

# Create a pie chart
plt.figure(figsize=(10, 8))
pie = plt.pie(total_deaths_by_county['Deaths'], labels=None, autopct='%1.1f%%', startangle=140, labeldistance=1.1, colors=plt.cm.Paired.colors)

# Add labels outside the pie chart
for i, (county, percent) in enumerate(zip(total_deaths_by_county['County'], total_deaths_by_county['Deaths'] / total_deaths * 100)):
    plt.text(1.15, 0.8 - i * 0.1, f'{county}: {percent:.1f}%', fontsize=10, color=pie[0][i].get_facecolor())

# Add a text annotation for the total number of deaths
plt.text(1.25, 1.05, f'Total Deaths\n{total_deaths}', ha='right', va='top', fontsize=14, bbox=dict(boxstyle='round', facecolor='white'))

plt.title('Total Deaths by County in Oklahoma')
plt.show()
